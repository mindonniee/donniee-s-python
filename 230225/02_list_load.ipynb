# %%
import os 
import pandas as pd

# %%
# 파일 리스트 생성
file_list = os.listdir("../csv/2017")

# %%
# 반복문을 이용해서 파일명들을 각각 print
# 각각 파일들을 pandas를 이용해서 파일을 로드하여 하나의 데이터 프레임으로 결합
# 결합은 유니언 결합(concat)을 사용하여 결합


# case 1 ( range 사용)
for i in range (0,len(file_list),1):
    print(file_list[i])

# case 2 (list 사용)
for i in file_list:
    print(i)
# Out:
# 201701_expense_list (2).csv
# 201701_expense_list.csv
# 201702_expense_list (2).csv
# 201702_expense_list.csv
# 201703_expense_list (2).csv
# 201703_expense_list.csv
# 201704_expense_list (2).csv
# 201704_expense_list.csv
# 201705_expense_list (2).csv
# 201705_expense_list.csv
# 201706_expense_list (2).csv
# 201706_expense_list.csv
# 201707_expense_list (2).csv
# 201707_expense_list.csv
# 201708_expense_list (2).csv
# 201708_expense_list.csv
# 201709_expense_list (2).csv
# 201709_expense_list.csv
# 201710_expense_list (2).csv
# 201710_expense_list.csv
# 201711_expense_list (2).csv
# 201711_expense_list.csv
# 201712_expense_list (2).csv
# 201712_expense_list.csv
# 201701_expense_list (2).csv
# 201701_expense_list.csv
# 201702_expense_list (2).csv
# 201702_expense_list.csv
# 201703_expense_list (2).csv
# 201703_expense_list.csv
# 201704_expense_list (2).csv
# 201704_expense_list.csv
# 201705_expense_list (2).csv
# 201705_expense_list.csv
# 201706_expense_list (2).csv
# 201706_expense_list.csv
# 201707_expense_list (2).csv
# 201707_expense_list.csv
# 201708_expense_list (2).csv
# 201708_expense_list.csv
# 201709_expense_list (2).csv
# 201709_expense_list.csv
# 201710_expense_list (2).csv
# 201710_expense_list.csv
# 201711_expense_list (2).csv
# 201711_expense_list.csv
# 201712_expense_list (2).csv
# 201712_expense_list.csv

# %%
# csv를 데이터 프레임으로 변경
#pd.read_csv(파일경로)

print('../csv/2017/'+ '201704_expense_list.csv')
# Out:
# ../csv/2017/201704_expense_list.csv

# %%
# 비어있는 데이터프레임을 total_df에 저장
# 문자열을 변수에 담아준다
# file_list를 반복한다 -> 리스트 항목 하나하나씩 i에 넣어서
# file_path 문자열과 i의 값을 출력
# file_path와 i를 합친 문자열 (상대주소)의 csv파일을 데이터프레임화 하여 df 변수에 저장


total_df = pd.DataFrame()

file_path = '../csv/2017/'

for i in file_list:
    #df = pd.read_csv(file_path + i)
    print(file_path + i)
    df=pd.read_csv(file_path+i)

    total_df = pd.concat([total_df, df], axis='rows').reset_index(drop=True) #ignore_index=True도 가능
# Out:
# ../csv/2017/201701_expense_list (2).csv
# ../csv/2017/201701_expense_list.csv
# ../csv/2017/201702_expense_list (2).csv
# ../csv/2017/201702_expense_list.csv
# ../csv/2017/201703_expense_list (2).csv
# ../csv/2017/201703_expense_list.csv
# ../csv/2017/201704_expense_list (2).csv
# ../csv/2017/201704_expense_list.csv
# ../csv/2017/201705_expense_list (2).csv
# ../csv/2017/201705_expense_list.csv
# ../csv/2017/201706_expense_list (2).csv
# ../csv/2017/201706_expense_list.csv
# ../csv/2017/201707_expense_list (2).csv
# ../csv/2017/201707_expense_list.csv
# ../csv/2017/201708_expense_list (2).csv
# ../csv/2017/201708_expense_list.csv
# ../csv/2017/201709_expense_list (2).csv
# ../csv/2017/201709_expense_list.csv
# ../csv/2017/201710_expense_list (2).csv
# ../csv/2017/201710_expense_list.csv
# ../csv/2017/201711_expense_list (2).csv
# ../csv/2017/201711_expense_list.csv
# ../csv/2017/201712_expense_list (2).csv
# ../csv/2017/201712_expense_list.csv

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140264 entries, 0 to 140263
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nid                140264 non-null  int64
#  1   title              140264 non-null  object
#  2   url                140264 non-null  object
#  3   dept_nm_lvl_1      140264 non-null  object
#  4   dept_nm_lvl_2      140148 non-null  object
#  5   dept_nm_lvl_3      122524 non-null  object
#  6   dept_nm_lvl_4      35878 non-null   object
#  7   dept_nm_lvl_5      6948 non-null    object
#  8   exec_yr            140264 non-null  int64
#  9   exec_month         140264 non-null  int64
#  10  expense_budget     6216 non-null    float64
#  11  expense_execution  5610 non-null    float64
#  12  category           2518 non-null    object
#  13  dept_nm_full       140106 non-null  object
#  14  exec_dt            140264 non-null  object
#  15  exec_loc           138720 non-null  object
#  16  exec_purpose       140220 non-null  object
#  17  target_nm          139194 non-null  object
#  18  payment_method     139858 non-null  object
#  19  exec_amount        140264 non-null  int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 21.4+ MB

# %%
'../csv/2017/'+file_list[0]
# Out:
# '../csv/2017/201701_expense_list (2).csv'

# %%
pd.read_csv('../csv/2017/'+file_list[0])
# Out:
#            nid                                       title  \
# 0     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4     11430252                2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...        ...                                         ...
# 5512  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5513  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5514  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5515  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
# 5516  15513286  2017년 1월 서울시본청_경제진흥본부_경제기획관_투자유치과 업무추진비 내역
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 1     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 2     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 3     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# 4     http://opengov.seoul.go.kr/public/11430252         서울시본청          복지본부
# ...                                          ...           ...           ...
# 5512  http://opengov.seoul.go.kr/public/15513286         서울시본청        경제진흥본부
# 5513  http://opengov.seoul.go.kr/public/15513286         서울시본청        경제진흥본부
# 5514  http://opengov.seoul.go.kr/public/15513286         서울시본청        경제진흥본부
# 5515  http://opengov.seoul.go.kr/public/15513286         서울시본청        경제진흥본부
# 5516  http://opengov.seoul.go.kr/public/15513286         서울시본청        경제진흥본부
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0         장애인복지정책과           NaN           NaN     2017           1
# 1         장애인복지정책과           NaN           NaN     2017           1
# 2         장애인복지정책과           NaN           NaN     2017           1
# 3         장애인복지정책과           NaN           NaN     2017           1
# 4         장애인복지정책과           NaN           NaN     2017           1
# ...            ...           ...           ...      ...         ...
# 5512         경제기획관         투자유치과           NaN     2017           1
# 5513         경제기획관         투자유치과           NaN     2017           1
# 5514         경제기획관         투자유치과           NaN     2017           1
# 5515         경제기획관         투자유치과           NaN     2017           1
# 5516         경제기획관         투자유치과           NaN     2017           1
#
#       expense_budget  expense_execution category   dept_nm_full  \
# 0                NaN                NaN      NaN  복지본부 장애인복지정책과
# 1                NaN                NaN      NaN  복지본부 장애인복지정책과
# 2                NaN                NaN      NaN  복지본부 장애인복지정책과
# 3                NaN                NaN      NaN  복지본부 장애인복지정책과
# 4                NaN                NaN      NaN  복지본부 장애인복지정책과
# ...              ...                ...      ...            ...
# 5512             NaN                NaN      NaN   경제진흥본부 투자유치과
# 5513             NaN                NaN      NaN   경제진흥본부 투자유치과
# 5514             NaN                NaN      NaN   경제진흥본부 투자유치과
# 5515             NaN                NaN      NaN   경제진흥본부 투자유치과
# 5516             NaN                NaN      NaN   경제진흥본부 투자유치과
#
#                exec_dt                               exec_loc  \
# 0     2017-01-26 13:10                          동해일식 (중구 무교동)
# 1     2017-01-25 22:41                           김앤장 (중구 무교로)
# 2     2017-01-24 12:35                         왕왕생고기 (중구 을지로)
# 3     2017-01-24 12:23                        서울불고기 (중구 남대문로)
# 4     2017-01-23 15:10                                서울시청신매점
# ...                ...                                    ...
# 5512  2017-01-11 13:01       차이79                  종로구 새문안로5길
# 5513  2017-01-06 12:58   강가                     서울 중구 세종대로136
# 5514  2017-01-04 12:47        이복만두                  중구 무교동 27
# 5515  2017-01-03 12:42  불고기브라더스                     중구 태평로 1가
# 5516  2017-01-02 12:47    이화수                     서울 중구 다동길16
#
#                             exec_purpose       target_nm payment_method  \
# 0                      기본소득과 장애인복지 논의간담회  장애인복지정책팀장 외 2명             카드
# 1                       장애인단체 활동지원 논의간담회  장애인복지정책과장 외 3명             카드
# 2                    장애인 기본돌봄 복지시책 논의간담회    장애인복지정책팀장외7명             카드
# 3                서울시일자리통합지원센터 운영개선 논의간담회    장애인복지정책과장외5명             카드
# 4                       부서운영에 필요한 음료수 구매      장애인복지정책과직원             카드
# ...                                  ...             ...            ...
# 5512    금융기관 보조금 지원계획수립관련    간담회 개최 비용지출       투자유치과장외5명             카드
# 5513         핀테크 산업지원시설 입주 관련 간담회 개최비용지출        금융협력관외6명             카드
# 5514          F사 투자유치 협의를 위한 간담회 개최 비용지출       투자유치과장외4명             카드
# 5515           핀테크사업 전략수립을 위한 간담회 개최비용지출     경제진흥본부장외10명             카드
# 5516  글로벌유수 타깃기업 발굴 용역 결과보고 간담회 개최 비용 지출       투자정책팀장외7명             카드
#
#       exec_amount
# 0           76000
# 1          102000
# 2           80000
# 3          112000
# 4           16000
# ...           ...
# 5512        27000
# 5513        70000
# 5514        57000
# 5515       152400
# 5516        57000
#
# [5517 rows x 20 columns]

# %%
file_list2 = os.listdir("../csv/2021")

# %%
for i in range(len(file_list2)):
    if file_list2[i] [-3:]=='csv':
        print(file_list2[i])
# Out:
# 202101_expense_list (2).csv
# 202101_expense_list.csv
# 202102_expense_list (2).csv
# 202102_expense_list.csv
# 202103_expense_list (2).csv
# 202103_expense_list.csv
# 202104_expense_list (2).csv
# 202104_expense_list.csv
# 202105_expense_list (2).csv
# 202105_expense_list.csv
# 202106_expense_list (2).csv
# 202106_expense_list.csv
# 202107_expense_list (2).csv
# 202107_expense_list.csv
# 202108_expense_list (2).csv
# 202108_expense_list.csv
# 202109_expense_list (2).csv
# 202109_expense_list.csv
# 202110_expense_list (2).csv
# 202110_expense_list.csv
# 202111_expense_list (2).csv
# 202111_expense_list.csv
# 202112_expense_list (2).csv
# 202112_expense_list.csv

# %%
for i in file_list2:
    if i.endswith('.csv'):
        print(i)
    # print(i.endswith('.csv'))
# Out:
# 202101_expense_list (2).csv
# 202101_expense_list.csv
# 202102_expense_list (2).csv
# 202102_expense_list.csv
# 202103_expense_list (2).csv
# 202103_expense_list.csv
# 202104_expense_list (2).csv
# 202104_expense_list.csv
# 202105_expense_list (2).csv
# 202105_expense_list.csv
# 202106_expense_list (2).csv
# 202106_expense_list.csv
# 202107_expense_list (2).csv
# 202107_expense_list.csv
# 202108_expense_list (2).csv
# 202108_expense_list.csv
# 202109_expense_list (2).csv
# 202109_expense_list.csv
# 202110_expense_list (2).csv
# 202110_expense_list.csv
# 202111_expense_list (2).csv
# 202111_expense_list.csv
# 202112_expense_list (2).csv
# 202112_expense_list.csv

# %%
file_path = '../csv/2017'

# %%
os.listdir(file_path)
# Out:
# ['201701_expense_list (2).csv',
#  '201701_expense_list.csv',
#  '201702_expense_list (2).csv',
#  '201702_expense_list.csv',
#  '201703_expense_list (2).csv',
#  '201703_expense_list.csv',
#  '201704_expense_list (2).csv',
#  '201704_expense_list.csv',
#  '201705_expense_list (2).csv',
#  '201705_expense_list.csv',
#  '201706_expense_list (2).csv',
#  '201706_expense_list.csv',
#  '201707_expense_list (2).csv',
#  '201707_expense_list.csv',
#  '201708_expense_list (2).csv',
#  '201708_expense_list.csv',
#  '201709_expense_list (2).csv',
#  '201709_expense_list.csv',
#  '201710_expense_list (2).csv',
#  '201710_expense_list.csv',
#  '201711_expense_list (2).csv',
#  '201711_expense_list.csv',
#  '201712_expense_list (2).csv',
#  '201712_expense_list.csv']

# %%
## 함수 생성
## 매개변수 2개, path, end_string
def list_df(path,end_string):
    # file_list 생성
    file_list = os.listdir(path)
    # 확장자가 end_srting과 같은 경우의 리스트만 추출

    #case 1
    file_list2 = []
    for i in file_list:
        if i.endswith(end_string):
            file_list2.append(i)
    
    #case 2
    file_list3 = [i for i in file_list if i.endswith(end_string)]
    print(file_list2==file_list3)

    # file_list2의 리스트 항목들을 데이터 프레임화하여 하나의 데이터프레임으로 결합

    # 비어있는 데이터프레임 생성
    total_df= pd.DataFrame()

    # file_list2의 항목들을 가지고 반복문 실행
    for i in file_list2:
        # path는 매개변수, i는 file_list 항목의 값
        if end_string == '.csv':
            df = pd.read_csv(path+i)
        elif end_string == '.json':
            df = pd.read_json(path+i)
        elif (end_string == '.xlsx'):
            df = pd.read_excel(path+i)
        else:
            return '확장자가 잘못 입력되었습니다.'
        

        # 불러온 데이터프레임을 total_df에 단순한 행 결합
        total_df = pd.concat([total_df,df], axis=0, ignore_index=True)
    # 합쳐진 데이터프레임을 리턴
    return total_df

# %%
list_df('../csv/2017/', '.csv')
# Out:
# True
#              nid                            title  \
# 0       11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 1       11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 2       11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 3       11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# 4       11430252     2017년 1월 장애인복지정책과 업무추진비 집행내역
# ...          ...                              ...
# 140259  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 140260  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 140261  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 140262  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 140263  14292506  2017년 12월 사업소_은평병원_원무과 업무추진비 내역
#
#                                                url dept_nm_lvl_1  \
# 0       http://opengov.seoul.go.kr/public/11430252         서울시본청
# 1       http://opengov.seoul.go.kr/public/11430252         서울시본청
# 2       http://opengov.seoul.go.kr/public/11430252         서울시본청
# 3       http://opengov.seoul.go.kr/public/11430252         서울시본청
# 4       http://opengov.seoul.go.kr/public/11430252         서울시본청
# ...                                            ...           ...
# 140259  http://opengov.seoul.go.kr/public/14292506           사업소
# 140260  http://opengov.seoul.go.kr/public/14292506           사업소
# 140261  http://opengov.seoul.go.kr/public/14292506           사업소
# 140262  http://opengov.seoul.go.kr/public/14292506           사업소
# 140263  http://opengov.seoul.go.kr/public/14292506           사업소
#
#        dept_nm_lvl_2 dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  \
# 0               복지본부      장애인복지정책과           NaN           NaN     2017
# 1               복지본부      장애인복지정책과           NaN           NaN     2017
# 2               복지본부      장애인복지정책과           NaN           NaN     2017
# 3               복지본부      장애인복지정책과           NaN           NaN     2017
# 4               복지본부      장애인복지정책과           NaN           NaN     2017
# ...              ...           ...           ...           ...      ...
# 140259          은평병원           원무과           NaN           NaN     2017
# 140260          은평병원           원무과           NaN           NaN     2017
# 140261          은평병원           원무과           NaN           NaN     2017
# 140262          은평병원           원무과           NaN           NaN     2017
# 140263          은평병원           원무과           NaN           NaN     2017
#
#         exec_month  expense_budget  expense_execution category   dept_nm_full  \
# 0                1             NaN                NaN      NaN  복지본부 장애인복지정책과
# 1                1             NaN                NaN      NaN  복지본부 장애인복지정책과
# 2                1             NaN                NaN      NaN  복지본부 장애인복지정책과
# 3                1             NaN                NaN      NaN  복지본부 장애인복지정책과
# 4                1             NaN                NaN      NaN  복지본부 장애인복지정책과
# ...            ...             ...                ...      ...            ...
# 140259          12             NaN                NaN      NaN            원무과
# 140260          12             NaN                NaN      NaN            원무과
# 140261          12             NaN                NaN      NaN            원무과
# 140262          12             NaN                NaN      NaN            원무과
# 140263          12             NaN                NaN      NaN            원무과
#
#                  exec_dt            exec_loc             exec_purpose  \
# 0       2017-01-26 13:10       동해일식 (중구 무교동)        기본소득과 장애인복지 논의간담회
# 1       2017-01-25 22:41        김앤장 (중구 무교로)         장애인단체 활동지원 논의간담회
# 2       2017-01-24 12:35      왕왕생고기 (중구 을지로)      장애인 기본돌봄 복지시책 논의간담회
# 3       2017-01-24 12:23     서울불고기 (중구 남대문로)  서울시일자리통합지원센터 운영개선 논의간담회
# 4       2017-01-23 15:10             서울시청신매점         부서운영에 필요한 음료수 구매
# ...                  ...                 ...                      ...
# 140259  2017-12-15 16:40    보리네생고깃간(서오릉로 12)        지역정신보건기관 업무협의 간담회
# 140260  2017-12-12 20:39  항아리홍어(불광동 281-159)     원무과 현안업무 추진직원 격려 간담회
# 140261  2017-12-04 21:17     횟집산이네(백련산로 160)    18년 예산편성 관련 직원 격려 간담회
# 140262  2017-12-05 18:21         삿뽀로(서오릉로 4)        인증 관련업무 직원 격려 간담회
# 140263  2017-12-06 18:00      스타벅스(응암동 96-1)         전문의 및 전공의 격려 다과회
#
#              target_nm payment_method  exec_amount
# 0       장애인복지정책팀장 외 2명             카드        76000
# 1       장애인복지정책과장 외 3명             카드       102000
# 2         장애인복지정책팀장외7명             카드        80000
# 3         장애인복지정책과장외5명             카드       112000
# 4           장애인복지정책과직원             카드        16000
# ...                ...            ...          ...
# 140259        병원장 외 4명             카드       112000
# 140260       원무과장 외 4명             카드       118000
# 140261       서무팀장 외 5명             카드       124000
# 140262       병원장 외 33명             카드       820000
# 140263       병원장 외 11명             카드       440000
#
# [140264 rows x 20 columns]

# %%
file_path=('../csv/2018')

# %%
os.listdir(file_path)
# Out:
# ['201801_expense_list (2).csv',
#  '201801_expense_list.csv',
#  '201802_expense_list (2).csv',
#  '201802_expense_list.csv',
#  '201803_expense_list (2).csv',
#  '201803_expense_list.csv',
#  '201804_expense_list (2).csv',
#  '201804_expense_list.csv',
#  '201805_expense_list (2).csv',
#  '201805_expense_list.csv',
#  '201806_expense_list (2).csv',
#  '201806_expense_list.csv',
#  '201807_expense_list (2).csv',
#  '201807_expense_list.csv',
#  '201808_expense_list (2).csv',
#  '201808_expense_list.csv',
#  '201809_expense_list (2).csv',
#  '201809_expense_list.csv',
#  '201810_expense_list (2).csv',
#  '201810_expense_list.csv',
#  '201811_expense_list (2).csv',
#  '201811_expense_list.csv',
#  '201812_expense_list (2).csv',
#  '201812_expense_list.csv']

# %%
df_2017 = list_df('../csv/2017/', '.csv')
df_2018 = list_df('../csv/2018/', '.csv')
# Out:
# True
# True

# %%
# json  데이터를 데이터프레임으로 로드

json_data = pd.read_json("../csv/2019/201901_expense_list (2).json")
json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6392 entries, 0 to 6391
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                6392 non-null   int64
#  1   title              6392 non-null   object
#  2   url                6392 non-null   object
#  3   dept_nm_lvl_1      6392 non-null   object
#  4   dept_nm_lvl_2      6392 non-null   object
#  5   dept_nm_lvl_3      6392 non-null   object
#  6   dept_nm_lvl_4      6392 non-null   object
#  7   dept_nm_lvl_5      6392 non-null   object
#  8   exec_yr            6392 non-null   int64
#  9   exec_month         6392 non-null   int64
#  10  expense_budget     318 non-null    float64
#  11  expense_execution  306 non-null    float64
#  12  category           6392 non-null   object
#  13  dept_nm_full       6392 non-null   object
#  14  exec_dt            6392 non-null   object
#  15  exec_loc           6392 non-null   object
#  16  exec_purpose       6392 non-null   object
#  17  target_nm          6392 non-null   object
#  18  payment_method     6392 non-null   object
#  19  exec_amount        6392 non-null   int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 998.9+ KB

# %%
# xlsx 파일을 로드하기 위한 엔진 라이브러리 설치
# !pip install openpyxl
# Out:
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\python311\lib\site-packages (3.1.1)
# Requirement already satisfied: et-xmlfile in c:\python311\lib\site-packages (from openpyxl) (1.1.0)

# %%
# 엑셀 데이터 로드
excel_data = pd.read_excel("../csv/2020/202001_expense_list (2).xlsx")
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nid                5282 non-null   int64
#  1   title              5282 non-null   object
#  2   url                5282 non-null   object
#  3   dept_nm_lvl_1      5282 non-null   object
#  4   dept_nm_lvl_2      5282 non-null   object
#  5   dept_nm_lvl_3      4198 non-null   object
#  6   dept_nm_lvl_4      1272 non-null   object
#  7   dept_nm_lvl_5      81 non-null     object
#  8   exec_yr            5282 non-null   int64
#  9   exec_month         5282 non-null   int64
#  10  expense_budget     355 non-null    float64
#  11  expense_execution  276 non-null    float64
#  12  category           224 non-null    object
#  13  dept_nm_full       5282 non-null   object
#  14  exec_dt            5282 non-null   object
#  15  exec_loc           5236 non-null   object
#  16  exec_purpose       5282 non-null   object
#  17  target_nm          5257 non-null   object
#  18  payment_method     5282 non-null   object
#  19  exec_amount        5282 non-null   int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 825.4+ KB

# %%
df_2019 = list_df("../csv/2019/", '.json')
df_2020 = list_df("../csv/2020/", '.xlsx')
# Out:
# True
# True

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141724 entries, 0 to 141723
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   nid                141724 non-null  int64
#  1   title              141724 non-null  object
#  2   url                141724 non-null  object
#  3   dept_nm_lvl_1      141724 non-null  object
#  4   dept_nm_lvl_2      141724 non-null  object
#  5   dept_nm_lvl_3      111186 non-null  object
#  6   dept_nm_lvl_4      37984 non-null   object
#  7   dept_nm_lvl_5      3202 non-null    object
#  8   exec_yr            141724 non-null  int64
#  9   exec_month         141724 non-null  int64
#  10  expense_budget     3646 non-null    float64
#  11  expense_execution  2676 non-null    float64
#  12  category           4246 non-null    object
#  13  dept_nm_full       141724 non-null  object
#  14  exec_dt            141724 non-null  object
#  15  exec_loc           140556 non-null  object
#  16  exec_purpose       141724 non-null  object
#  17  target_nm          140976 non-null  object
#  18  payment_method     141724 non-null  object
#  19  exec_amount        141724 non-null  int64
#  20  bimok              566 non-null     object
# dtypes: float64(2), int64(4), object(15)
# memory usage: 22.7+ MB

# %%
## 모듈 로드
import list_pandas

## 모듈 리로드
import imp
imp.reload(list_pandas)
# Out:
# C:\Users\ezen\AppData\Local\Temp\ipykernel_616\1316756927.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'list_pandas' from 'c:\\Users\\ezen\\Desktop\\donniee-s-python-main\\230225\\list_pandas.py'>

# %%
list_pandas.list_df('../csv/2017/', '.csv')
# Out:
# True
#            nid                             title  \
# 0     14356805  2017년 12월 서울시본청_행정국_인사과 업무추진비 내역
# 1     14356805  2017년 12월 서울시본청_행정국_인사과 업무추진비 내역
# 2     14356805  2017년 12월 서울시본청_행정국_인사과 업무추진비 내역
# 3     14356805  2017년 12월 서울시본청_행정국_인사과 업무추진비 내역
# 4     14356805  2017년 12월 서울시본청_행정국_인사과 업무추진비 내역
# ...        ...                               ...
# 7281  14292506   2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7282  14292506   2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7283  14292506   2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7284  14292506   2017년 12월 사업소_은평병원_원무과 업무추진비 내역
# 7285  14292506   2017년 12월 사업소_은평병원_원무과 업무추진비 내역
#
#                                              url dept_nm_lvl_1 dept_nm_lvl_2  \
# 0     http://opengov.seoul.go.kr/public/14356805         서울시본청           행정국
# 1     http://opengov.seoul.go.kr/public/14356805         서울시본청           행정국
# 2     http://opengov.seoul.go.kr/public/14356805         서울시본청           행정국
# 3     http://opengov.seoul.go.kr/public/14356805         서울시본청           행정국
# 4     http://opengov.seoul.go.kr/public/14356805         서울시본청           행정국
# ...                                          ...           ...           ...
# 7281  http://opengov.seoul.go.kr/public/14292506           사업소          은평병원
# 7282  http://opengov.seoul.go.kr/public/14292506           사업소          은평병원
# 7283  http://opengov.seoul.go.kr/public/14292506           사업소          은평병원
# 7284  http://opengov.seoul.go.kr/public/14292506           사업소          은평병원
# 7285  http://opengov.seoul.go.kr/public/14292506           사업소          은평병원
#
#      dept_nm_lvl_3 dept_nm_lvl_4 dept_nm_lvl_5  exec_yr  exec_month  \
# 0              인사과           NaN           NaN     2017          12
# 1              인사과           NaN           NaN     2017          12
# 2              인사과           NaN           NaN     2017          12
# 3              인사과           NaN           NaN     2017          12
# 4              인사과           NaN           NaN     2017          12
# ...            ...           ...           ...      ...         ...
# 7281           원무과           NaN           NaN     2017          12
# 7282           원무과           NaN           NaN     2017          12
# 7283           원무과           NaN           NaN     2017          12
# 7284           원무과           NaN           NaN     2017          12
# 7285           원무과           NaN           NaN     2017          12
#
#       expense_budget  expense_execution category dept_nm_full  \
# 0                NaN                NaN      NaN      행정국 인사과
# 1                NaN                NaN      NaN      행정국 인사과
# 2                NaN                NaN      NaN      행정국 인사과
# 3                NaN                NaN      NaN      행정국 인사과
# 4                NaN                NaN      NaN      행정국 인사과
# ...              ...                ...      ...          ...
# 7281             NaN                NaN      NaN          원무과
# 7282             NaN                NaN      NaN          원무과
# 7283             NaN                NaN      NaN          원무과
# 7284             NaN                NaN      NaN          원무과
# 7285             NaN                NaN      NaN          원무과
#
#                exec_dt            exec_loc                  exec_purpose  \
# 0     2017-12-28 22:44      김앤장 (중구 무교로 6)   정년명예퇴임식 개선사항 검토를 위한 간담회비 지급
# 1     2017-12-28 15:48      황금정 (종로구 당주동1)  퇴임식 행사 진행순서 논의 등을 위한 간담회비 지급
# 2     2017-12-27 20:45    CJ푸드빌 (중구 을지로3길)  퇴임식 행사용역 중간 점검 등을 위한 간담회비 지급
# 3     2017-12-26 21:28   우리집순두부 (중구 을지로3길)     직원 인사교류 관련 검토를 위한 간담회비 지급
# 4     2017-12-26 19:36      소호정 (중구 태평로1가)     공무직 인사제도 개선논의를 위한 간담회비 지급
# ...                ...                 ...                           ...
# 7281  2017-12-15 16:40    보리네생고깃간(서오릉로 12)             지역정신보건기관 업무협의 간담회
# 7282  2017-12-12 20:39  항아리홍어(불광동 281-159)          원무과 현안업무 추진직원 격려 간담회
# 7283  2017-12-04 21:17     횟집산이네(백련산로 160)         18년 예산편성 관련 직원 격려 간담회
# 7284  2017-12-05 18:21         삿뽀로(서오릉로 4)             인증 관련업무 직원 격려 간담회
# 7285  2017-12-06 18:00      스타벅스(응암동 96-1)              전문의 및 전공의 격려 다과회
#
#           target_nm payment_method  exec_amount
# 0      인사기획팀장 등 12명             카드       300000
# 1      성과관리팀장 등 13명             카드       380000
# 2      인사기획팀장 등 15명             카드       425000
# 3       인사기획팀장 등 5명             카드       117000
# 4     공무공공안전팀장 등 6명             카드       170000
# ...             ...            ...          ...
# 7281       병원장 외 4명             카드       112000
# 7282      원무과장 외 4명             카드       118000
# 7283      서무팀장 외 5명             카드       124000
# 7284      병원장 외 33명             카드       820000
# 7285      병원장 외 11명             카드       440000
#
# [7286 rows x 20 columns]
